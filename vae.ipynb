# %%
import torch
import torch.utils.data
from torch import nn, optim
from torch.nn import functional as F
from torchvision import datasets, transforms
from torchvision.utils import save_image

class Args:
    def __init__(self):
        self.batch_size = 100
        self.epochs = 100
        self.no_cuda = False
        self.cuda = False
        self.seed = 1
        self.log_interval = 10
        
args = Args()
args.cuda = not args.no_cuda and torch.cuda.is_available()

torch.manual_seed(args.seed)

device = torch.device("cuda" if args.cuda else "cpu")

kwargs = {'num_workers': 1, 'pin_memory': True} if args.cuda else {}
train_loader = torch.utils.data.DataLoader(
    datasets.MNIST('./data', train=True, download=True,
                   transform=transforms.ToTensor()),
    batch_size=args.batch_size, shuffle=True, **kwargs)
test_loader = torch.utils.data.DataLoader(
    datasets.MNIST('./data', train=False, transform=transforms.ToTensor()),
    batch_size=args.batch_size, shuffle=True, **kwargs)


class VAE(nn.Module):
    def __init__(self):
        super(VAE, self).__init__()

        self.fc1 = nn.Linear(784, 400)
        self.fc21 = nn.Linear(400, 20)
        self.fc22 = nn.Linear(400, 20)
        self.fc3 = nn.Linear(20, 400)
        self.fc4 = nn.Linear(400, 784)

    def encode(self, x):
        h1 = F.relu(self.fc1(x))
        return self.fc21(h1), self.fc22(h1)

    def reparameterize(self, mu, logvar):
        std = torch.exp(0.5*logvar)
        eps = torch.randn_like(std)
        return mu + eps*std

    def decode(self, z):
        h3 = F.relu(self.fc3(z))
        return torch.sigmoid(self.fc4(h3))

    def forward(self, x):
        mu, logvar = self.encode(x.view(-1, 784))
        z = self.reparameterize(mu, logvar)
        return self.decode(z), mu, logvar


model = VAE().to(device)
optimizer = optim.Adam(model.parameters(), lr=1e-3)


# Reconstruction + KL divergence losses summed over all elements and batch
def loss_function(recon_x, x, mu, logvar):
    BCE = F.binary_cross_entropy(recon_x, x.view(-1, 784), reduction='sum')

    # see Appendix B from VAE paper:
    # Kingma and Welling. Auto-Encoding Variational Bayes. ICLR, 2014
    # https://arxiv.org/abs/1312.6114
    # 0.5 * sum(1 + log(sigma^2) - mu^2 - sigma^2)
    KLD = -0.5 * torch.sum(1 + logvar - mu.pow(2) - logvar.exp())

    return BCE + KLD


def train(epoch):
    model.train()
    train_loss = 0
    for batch_idx, (data, _) in enumerate(train_loader):
        data = data.to(device)
        optimizer.zero_grad()
        recon_batch, mu, logvar = model(data)
        loss = loss_function(recon_batch, data, mu, logvar)
        loss.backward()
        train_loss += loss.item()
        optimizer.step()
        # if batch_idx % args.log_interval == 0:
            # print('Train Epoch: {} [{}/{} ({:.0f}%)]\tLoss: {:.6f}'.format(
            #     epoch, batch_idx * len(data), len(train_loader.dataset),
            #     100. * batch_idx / len(train_loader),
            #     loss.item() / len(data)))

    print('====> Epoch: {} Average loss: {:.4f}'.format(
          epoch, train_loss / len(train_loader.dataset)))


def test(epoch):
    model.eval()
    test_loss = 0
    with torch.no_grad():
        for i, (data, _) in enumerate(test_loader):
            data = data.to(device)
            recon_batch, mu, logvar = model(data)
            test_loss += loss_function(recon_batch, data, mu, logvar).item()
            if i == 0:
                n = min(data.size(0), 8)
                comparison = torch.cat([data[:n],
                                      recon_batch.view(args.batch_size, 1, 28, 28)[:n]])
                # save_image(comparison.cpu(),
                #          'results/reconstruction_' + str(epoch) + '.png', nrow=n)

    test_loss /= len(test_loader.dataset)
    print('====> Test set loss: {:.4f}'.format(test_loss))

if __name__ == "__main__":
    for epoch in range(1, args.epochs + 1):
        train(epoch)
        test(epoch)
        with torch.no_grad():
            sample = torch.randn(args.batch_size, 20).to(device)
            sample = model.decode(sample).cpu()
            save_image(sample.view(args.batch_size, 1, 28, 28),
                       'results/sample_' + str(epoch) + '.png', nrow=10)
# Out:
# ====> Epoch: 1 Average loss: 158.1568
# ====> Test set loss: 123.4517
# ====> Epoch: 2 Average loss: 118.5835
# ====> Test set loss: 113.5238
# ====> Epoch: 3 Average loss: 112.7208
# ====> Test set loss: 110.2744
# ====> Epoch: 4 Average loss: 110.1323
# ====> Test set loss: 108.5987
# ====> Epoch: 5 Average loss: 108.6874
# ====> Test set loss: 107.5313
# ====> Epoch: 6 Average loss: 107.6973
# ====> Test set loss: 106.7177
# ====> Epoch: 7 Average loss: 106.9178
# ====> Test set loss: 106.0455
# ====> Epoch: 8 Average loss: 106.4166
# ====> Test set loss: 105.5883
# ====> Epoch: 9 Average loss: 105.9566
# ====> Test set loss: 105.2344
# ====> Epoch: 10 Average loss: 105.5980
# ====> Test set loss: 104.9465
# ====> Epoch: 11 Average loss: 105.2808
# ====> Test set loss: 104.7643
# ====> Epoch: 12 Average loss: 104.9775
# ====> Test set loss: 104.5502
# ====> Epoch: 13 Average loss: 104.7578
# ====> Test set loss: 104.4225
# ====> Epoch: 14 Average loss: 104.5165
# ====> Test set loss: 103.9580
# ====> Epoch: 15 Average loss: 104.3359
# ====> Test set loss: 104.0192
# ====> Epoch: 16 Average loss: 104.1771
# ====> Test set loss: 103.7956
# ====> Epoch: 17 Average loss: 103.9854
# ====> Test set loss: 103.5823
# ====> Epoch: 18 Average loss: 103.8189
# ====> Test set loss: 103.4627
# ====> Epoch: 19 Average loss: 103.6767
# ====> Test set loss: 103.3924
# ====> Epoch: 20 Average loss: 103.5592
# ====> Test set loss: 103.2717
# ====> Epoch: 21 Average loss: 103.4560
# ====> Test set loss: 103.2326
# ====> Epoch: 22 Average loss: 103.2632
# ====> Test set loss: 103.2664
# ====> Epoch: 23 Average loss: 103.1793
# ====> Test set loss: 102.9618
# ====> Epoch: 24 Average loss: 103.1143
# ====> Test set loss: 102.8168
# ====> Epoch: 25 Average loss: 103.0253
# ====> Test set loss: 102.8485
# ====> Epoch: 26 Average loss: 102.8830
# ====> Test set loss: 102.6171
# ====> Epoch: 27 Average loss: 102.8207
# ====> Test set loss: 102.6879
# ====> Epoch: 28 Average loss: 102.7404
# ====> Test set loss: 102.8327
# ====> Epoch: 29 Average loss: 102.6601
# ====> Test set loss: 102.5066
# ====> Epoch: 30 Average loss: 102.5605
# ====> Test set loss: 102.5885
# ====> Epoch: 31 Average loss: 102.4910
# ====> Test set loss: 102.3013
# ====> Epoch: 32 Average loss: 102.4390
# ====> Test set loss: 102.4932
# ====> Epoch: 33 Average loss: 102.3344
# ====> Test set loss: 102.2725
# ====> Epoch: 34 Average loss: 102.2978
# ====> Test set loss: 102.1472
# ====> Epoch: 35 Average loss: 102.2417
# ====> Test set loss: 102.2417
# ====> Epoch: 36 Average loss: 102.1509
# ====> Test set loss: 102.2432
# ====> Epoch: 37 Average loss: 102.0769
# ====> Test set loss: 101.9441
# ====> Epoch: 38 Average loss: 102.0758
# ====> Test set loss: 102.2928
# ====> Epoch: 39 Average loss: 101.9680
# ====> Test set loss: 102.0651
# ====> Epoch: 40 Average loss: 101.9709
# ====> Test set loss: 102.0148
# ====> Epoch: 41 Average loss: 101.9270
# ====> Test set loss: 101.9617
# ====> Epoch: 42 Average loss: 101.8647
# ====> Test set loss: 101.8616
# ====> Epoch: 43 Average loss: 101.7589
# ====> Test set loss: 101.9206
# ====> Epoch: 44 Average loss: 101.7526
# ====> Test set loss: 101.7884
# ====> Epoch: 45 Average loss: 101.6906
# ====> Test set loss: 102.0555
# ====> Epoch: 46 Average loss: 101.6528
# ====> Test set loss: 101.6894
# ====> Epoch: 47 Average loss: 101.6177
# ====> Test set loss: 101.7771
# ====> Epoch: 48 Average loss: 101.6137
# ====> Test set loss: 101.9299
# ====> Epoch: 49 Average loss: 101.5120
# ====> Test set loss: 101.7748
# ====> Epoch: 50 Average loss: 101.5019
# ====> Test set loss: 101.6419
# ====> Epoch: 51 Average loss: 101.4872
# ====> Test set loss: 101.5747
# ====> Epoch: 52 Average loss: 101.4358
# ====> Test set loss: 101.9782
# ====> Epoch: 53 Average loss: 101.3634
# ====> Test set loss: 101.6308
# ====> Epoch: 54 Average loss: 101.3391
# ====> Test set loss: 101.6186
# ====> Epoch: 55 Average loss: 101.3229
# ====> Test set loss: 101.4431
# ====> Epoch: 56 Average loss: 101.2909
# ====> Test set loss: 101.3861
# ====> Epoch: 57 Average loss: 101.2603
# ====> Test set loss: 101.6498
# ====> Epoch: 58 Average loss: 101.2561
# ====> Test set loss: 101.6146
# ====> Epoch: 59 Average loss: 101.1844
# ====> Test set loss: 101.5579
# ====> Epoch: 60 Average loss: 101.1404
# ====> Test set loss: 101.2863
# ====> Epoch: 61 Average loss: 101.1047
# ====> Test set loss: 101.4664
# ====> Epoch: 62 Average loss: 101.0875
# ====> Test set loss: 101.1967
# ====> Epoch: 63 Average loss: 101.0548
# ====> Test set loss: 101.2560
# ====> Epoch: 64 Average loss: 101.0662
# ====> Test set loss: 101.3128
# ====> Epoch: 65 Average loss: 100.9850
# ====> Test set loss: 101.2727
# ====> Epoch: 66 Average loss: 101.0023
# ====> Test set loss: 101.1476
# ====> Epoch: 67 Average loss: 100.9459
# ====> Test set loss: 101.3433
# ====> Epoch: 68 Average loss: 100.9679
# ====> Test set loss: 101.2343
# ====> Epoch: 69 Average loss: 100.9079
# ====> Test set loss: 101.2770
# ====> Epoch: 70 Average loss: 100.9085
# ====> Test set loss: 101.3064
# ====> Epoch: 71 Average loss: 100.8675
# ====> Test set loss: 101.1576
# ====> Epoch: 72 Average loss: 100.8845
# ====> Test set loss: 101.4310
# ====> Epoch: 73 Average loss: 100.8273
# ====> Test set loss: 100.8726
# ====> Epoch: 74 Average loss: 100.7764
# ====> Test set loss: 101.1373
# ====> Epoch: 75 Average loss: 100.7992
# ====> Test set loss: 101.0235
# ====> Epoch: 76 Average loss: 100.7666
# ====> Test set loss: 101.2100
# ====> Epoch: 77 Average loss: 100.7296
# ====> Test set loss: 101.0156
# ====> Epoch: 78 Average loss: 100.7150
# ====> Test set loss: 101.1349
# ====> Epoch: 79 Average loss: 100.6855
# ====> Test set loss: 101.0739
# ====> Epoch: 80 Average loss: 100.6809
# ====> Test set loss: 101.1014
# ====> Epoch: 81 Average loss: 100.6433
# ====> Test set loss: 101.1232
# ====> Epoch: 82 Average loss: 100.6334
# ====> Test set loss: 100.8287
# ====> Epoch: 83 Average loss: 100.6328
# ====> Test set loss: 100.8514
# ====> Epoch: 84 Average loss: 100.5580
# ====> Test set loss: 100.9661
# ====> Epoch: 85 Average loss: 100.5196
# ====> Test set loss: 101.1570
# ====> Epoch: 86 Average loss: 100.5379
# ====> Test set loss: 101.1213
# ====> Epoch: 87 Average loss: 100.5279
# ====> Test set loss: 101.0008
# ====> Epoch: 88 Average loss: 100.5319
# ====> Test set loss: 101.0599
# ====> Epoch: 89 Average loss: 100.5072
# ====> Test set loss: 100.9142
# ====> Epoch: 90 Average loss: 100.5149
# ====> Test set loss: 100.8284
# ====> Epoch: 91 Average loss: 100.4553
# ====> Test set loss: 100.8469
# ====> Epoch: 92 Average loss: 100.4525
# ====> Test set loss: 100.7643
# ====> Epoch: 93 Average loss: 100.4271
# ====> Test set loss: 100.6571
# ====> Epoch: 94 Average loss: 100.4220
# ====> Test set loss: 100.7684
# ====> Epoch: 95 Average loss: 100.3907
# ====> Test set loss: 100.7813
# ====> Epoch: 96 Average loss: 100.3982
# ====> Test set loss: 100.8890
# ====> Epoch: 97 Average loss: 100.3612
# ====> Test set loss: 100.8603
# ====> Epoch: 98 Average loss: 100.3151
# ====> Test set loss: 100.7395
# ====> Epoch: 99 Average loss: 100.3442
# ====> Test set loss: 100.7884
# ====> Epoch: 100 Average loss: 100.3522
# ====> Test set loss: 100.6844

# %%
sample = torch.randn(args.batch_size, 20).to(device)
sample[:,0] -= 1
sample[:,1] += 1
sample[:,2] -= 1
sample[:,3] += 1
sample[:,4] -= 1
sample[:,5] += 1
sample[:,6] -= 1
sample[:,7] += 1
for ii in range(0, 21):
    sample[:,0] += 0.1
    sample[:,1] -= 0.1
    sample[:,2] += 0.1
    sample[:,3] -= 0.1
    sample[:,4] += 0.1
    sample[:,5] -= 0.1
    sample[:,6] += 0.1
    sample[:,7] -= 0.1
    print(torch.mean(sample))
    images = model.decode(sample).cpu()
    save_image(images.view(args.batch_size, 1, 28, 28)[11,:],
                       'results/pertubation_test_' + str(ii) + '.png', nrow=10)
# Out:
# tensor(-0.0208, device='cuda:0')
# tensor(-0.0208, device='cuda:0')
# tensor(-0.0208, device='cuda:0')
# tensor(-0.0208, device='cuda:0')
# tensor(-0.0208, device='cuda:0')
# tensor(-0.0208, device='cuda:0')
# tensor(-0.0208, device='cuda:0')
# tensor(-0.0208, device='cuda:0')
# tensor(-0.0208, device='cuda:0')
# tensor(-0.0208, device='cuda:0')
# tensor(-0.0208, device='cuda:0')
# tensor(-0.0208, device='cuda:0')
# tensor(-0.0208, device='cuda:0')
# tensor(-0.0208, device='cuda:0')
# tensor(-0.0208, device='cuda:0')
# tensor(-0.0208, device='cuda:0')
# tensor(-0.0208, device='cuda:0')
# tensor(-0.0208, device='cuda:0')
# tensor(-0.0208, device='cuda:0')
# tensor(-0.0208, device='cuda:0')
# tensor(-0.0208, device='cuda:0')
